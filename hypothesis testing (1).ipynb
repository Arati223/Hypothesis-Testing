# %% [markdown]
# One Tailed Test

# %%
# One Tail Test
import pandas as pd
from scipy import stats

# %%
data=pd.Series([0.593,0.142,0.329,0.691,0.231,0.793,0.519,0.392,0.418])

# %%
data
# Out:
# 0    0.593
# 1    0.142
# 2    0.329
# 3    0.691
# 4    0.231
# 5    0.793
# 6    0.519
# 7    0.392
# 8    0.418
# dtype: float64

# %%
stats.ttest_1samp(data,0.3)
#Ttest_1sampResult(statistic=2.2050588385131595,pvalue=0.05853)
# Out:
# Ttest_1sampResult(statistic=2.2050588385131595, pvalue=0.05853032968489765)

# %%
#This gives two tail test p value so divide by 2 to get final p-value
p= stats.ttest_1samp(data,0.3)[1]
p
# Out:
# 0.05853032968489765

# %%
p_value=p/2
p_value
# Out:
# 0.029265164842448826

# %% [markdown]
# Two Tailed Test

# %%
# Two tail test
Control=pd.Series([91,87,99,77,88,91])
Treat=pd.Series([101, 110, 103, 93, 99, 104])

stats.ttest_ind(Control,Treat)
stats.ttest_ind(Control,Treat)

# %%
stats.ttest_ind(Control,Treat)
# Out:
# Ttest_indResult(statistic=-3.4456126735364876, pvalue=0.006272124350809803)

# %%
McDonald=pd.Series([])
Kimling=pd.Series([1,2,3,1,3,2,4,5,2,5])

# %%
stats.ttest_ind(McDonald,Kimling)
# Out:
# Ttest_indResult(statistic=0.16151457061744978, pvalue=0.8734872283133773)

# %% [markdown]
# Anova

# %%
#Load libraries
from sklearn import datasets

# %%
#Load iris datasets
iris = datasets.load_iris()

# %%
iris.data
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(iris.data)
df
# Out:
#        0    1    2    3
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# ..   ...  ...  ...  ...
# 145  6.7  3.0  5.2  2.3
# 146  6.3  2.5  5.0  1.9
# 147  6.5  3.0  5.2  2.0
# 148  6.2  3.4  5.4  2.3
# 149  5.9  3.0  5.1  1.8
#
# [150 rows x 4 columns]

# %%
import scipy.stats as stats

# %%
stats.f_oneway(df[0],df[1],df[2])
# Out:
# F_onewayResult(statistic=236.75163298404746, pvalue=7.657188374182084e-71)

# %%
df=pd.read_csv("https://raw.githubusercontent.com/slmsshk/DataSet/main/penguins.csv")

# %%
df=df.dropna()
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
df.species.value_counts()
# Out:
# Adelie       146
# Gentoo       119
# Chinstrap     68
# Name: species, dtype: int64

# %%
A=df[df['species']=='Adelie']
A
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 147  Adelie      Dream            36.6           18.4              184.0
# 148  Adelie      Dream            36.0           17.8              195.0
# 149  Adelie      Dream            37.8           18.1              193.0
# 150  Adelie      Dream            36.0           17.1              187.0
# 151  Adelie      Dream            41.5           18.5              201.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
C=df[df['species']=='Gentoo']
C
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 220  Gentoo  Biscoe            46.1           13.2              211.0
# 221  Gentoo  Biscoe            50.0           16.3              230.0
# 222  Gentoo  Biscoe            48.7           14.1              210.0
# 223  Gentoo  Biscoe            50.0           15.2              218.0
# 224  Gentoo  Biscoe            47.6           14.5              215.0
# ..      ...     ...             ...            ...                ...
# 338  Gentoo  Biscoe            47.2           13.7              214.0
# 340  Gentoo  Biscoe            46.8           14.3              215.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 220       4500.0  FEMALE
# 221       5700.0    MALE
# 222       4450.0  FEMALE
# ...

# %%
D=df[df['species']=='Chinstrap']
D
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152  Chinstrap  Dream            46.5           17.9              192.0
# 153  Chinstrap  Dream            50.0           19.5              196.0
# 154  Chinstrap  Dream            51.3           19.2              193.0
# 155  Chinstrap  Dream            45.4           18.7              188.0
# 156  Chinstrap  Dream            52.7           19.8              197.0
# ..         ...    ...             ...            ...                ...
# 215  Chinstrap  Dream            55.8           19.8              207.0
# 216  Chinstrap  Dream            43.5           18.1              202.0
# 217  Chinstrap  Dream            49.6           18.2              193.0
# 218  Chinstrap  Dream            50.8           19.0              210.0
# 219  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex
# 152       3500.0  FEMALE
# 153       3900.0    MALE
# ...

# %%
stats.f_oneway(A['bill_length_mm'],C['bill_length_mm'],D['bill_length_mm'])
# Out:
# F_onewayResult(statistic=397.29943741282796, pvalue=1.3809842053151752e-88)

# %%
stats.f_oneway(A['body_mass_g'],C['body_mass_g'],D['body_mass_g'])
# Out:
# F_onewayResult(statistic=341.8948949481462, pvalue=3.744505126300355e-81)
